# %% [markdown]
# Setup

# %%
# If on Colab, mount Drive first
from google.colab import drive
drive.mount('/content/drive')

# Then clone/pull repo (your usual cells)
import os
REPO = "LaneDetection"
if not os.path.exists(f"/content/{REPO}"):
    # !git clone https://github.com/abdullahtapanci/LaneDetection.git /content/{REPO}
else:
    # !cd /content/{REPO} && git pull
# %cd /content/{REPO}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Already up to date.
# /content/LaneDetection

# %%
import cv2
import matplotlib.pyplot as plt
from src.data.transforms import transform_image

# %% [markdown]
# Define pipeline

# %%
traintxt = "/content/drive/MyDrive/Lane_Detection_Project/data/tusimple/train.txt"

with open(traintxt, "r") as f:
    lines = f.readlines()


ROOT = "/content/drive/MyDrive/Lane_Detection_Project/data/tusimple/"
image_path, bin_path, inst_path = lines[0].strip().split()

# Load images
image = cv2.imread(image_path)
binary_mask = cv2.imread(bin_path, 0)
instance_mask = cv2.imread(inst_path, 0)

augmented = transform_image(image_path, bin_path, inst_path)

aug_image = augmented["image"]
aug_binary = augmented["masks"][0]
aug_instance = augmented["masks"][1]


# Show results
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

# Original row
axes[0,0].imshow(image)
axes[0,0].set_title("Original Image")

axes[0,1].imshow(binary_mask, cmap="gray")
axes[0,1].set_title("Original Binary Mask")

axes[0,2].imshow(instance_mask)
axes[0,2].set_title("Original Instance Mask")

# Augmented row
axes[1,0].imshow(aug_image)
axes[1,0].set_title("Augmented Image")

axes[1,1].imshow(aug_binary, cmap="gray")
axes[1,1].set_title("Augmented Binary Mask")

axes[1,2].imshow(aug_instance)
axes[1,2].set_title("Augmented Instance Mask")

for ax in axes.flatten():
    ax.axis("off")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_14659/748562533.py in <cell line: 0>()
#      14 instance_mask = cv2.imread(inst_path, 0)
#      15
# ---> 16 augmented = transform_image(image_path, bin_path, inst_path)
#      17
#      18 aug_image = augmented["image"]
#
# /content/LaneDetection/src/data/transforms.py in transform_image(image_path, bin_path, inst_path)
#       7     #Here we load and resize image
#       8     img = cv2.imread(image_path)
# ----> 9     img = cv2.resize(img, (cfg.IMAGE_WIDTH, cfg.IMAGE_HEIGHT))
#      10     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      11
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
